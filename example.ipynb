# %%
from  juno_adx_client import ADXClient

cluster_url = "..."
use_interactive_login = "..."

client = ADXClient(cluster_url, interactive_login=use_interactive_login)

# %%
database_name = "..."
query_text = "..."

client.perform_query(query=query_text, database=database_name)
# Out:
#            TableName           DatabaseName Folder DocString
# 0  NO_33_12_N_3_HHT2  MSP Surface Time VLOG   None      None
# 1    NO_33_12_N_3_IH  MSP Surface Time VLOG   None      None
# 2    NO_34_10_C_27_A  MSP Surface Time VLOG   None      None
# 3  NO_34_10_C_27_AT2  MSP Surface Time VLOG   None      None
# 4  NO_34_10_B_29_DT2  MSP Surface Time VLOG   None      None
# 5    NO_34_10_G_4_CH  MSP Surface Time VLOG   None      None
# 6    NO_34_10_G_4_DH  MSP Surface Time VLOG   None      None
# 7    NO_34_10_A_31_B  MSP Surface Time VLOG   None      None
# 8  NO_34_10_B_29_DT3  MSP Surface Time VLOG   None      None
